# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriosilva/lunar-lander/blob/main/Lunar_Lander_Assignement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Import the Required Libraries

# %% [markdown]
# ## Install the Required Libraries

# %%
# !pip install gymnasium
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install imageio imageio-ffmpeg
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Collecting swig
#   Downloading swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.2 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.2.1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.2.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2376102 sha256=c795d000eb9a3819608f82c95314854c6b5593edad27a4dc21fdebf193bacb5d
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (0.4.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.25.2)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg) (67.7.2)

# %% [markdown]
# ## Import the Required Libraries

# %%
from collections import deque, namedtuple
import matplotlib.pyplot as plt
import gymnasium as gym
import numpy as np
import pandas as pd

from torch import nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import random
from IPython.display import display
from IPython.display import Video

# %% [markdown]
# # Introduction
# In this notebook, we will implement a Deep Q-Network (DQN) to solve the Lunar Lander environment from the OpenAI Gym. The Lunar Lander environment is a continuous state and discrete action space environment where the agent has to learn to land a spacecraft on the moon. The agent receives a reward for landing the spacecraft safely and a penalty for crashing the spacecraft. The environment is considered solved when the agent achieves an average reward of 200 over 100 consecutive episodes.

# %% [markdown]
# ### Set the Device
# We are setting the device to be used for training the network. If a GPU is available, we will use it; otherwise, we will use the CPU.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Define the DQN Network
# Here, we define the DQN network using the PyTorch library. The network consists of three fully connected layers with ReLU activation functions. The input size of the network is the state size, and the output size is the action size. The network is defined as a class that inherits from the nn.Module class. The forward method is used to define the forward pass of the network.

# %%
class DQNNetwork(nn.Module):
    """
    Implements a Deep Q-Network (DQN) using PyTorch's nn.Module as the base class.

    Attributes:
        seed (int): Random seed for reproducibility.
        state_size (int): Dimension of each state input.
        action_size (int): Number of possible actions.
        layer1 (torch.nn.Linear): First hidden layer.
        layer2 (torch.nn.Linear): Second hidden layer.
        layer3 (torch.nn.Linear): Output layer producing action values.

    Args:
        state_size (int): The dimensionality of the state space.
        action_size (int): The dimensionality of the action space.
        seed (int): Seed for random number generators to ensure reproducibility.
        hidden_size (int, optional): Number of nodes in the hidden layers. Defaults to 128.
    """

    def __init__(self, state_size, action_size, seed, hidden_size=128):
        super(DQNNetwork, self).__init__()
        self.seed =  torch.manual_seed(seed)
        self.state_size = state_size
        self.action_size = action_size
        self.layer1 = nn.Linear(state_size, hidden_size)
        self.layer2 = nn.Linear(hidden_size, hidden_size)
        self.layer3 = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        """
        Defines the forward pass of the network.

        Args:
            x (Tensor): The input state.

        Returns:
            Tensor: The output action values.
        """
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = self.layer3(x)
        return x

# %% [markdown]
# ## Define the Replay Buffer
# We define the replay buffer that stores the experiences of the agent. The replay buffer is used to store the experiences of the agent in the form of a tuple containing the state, action, reward, next state, and done flag. The replay buffer has a method to add experiences and a method to sample a batch of experiences for training the network.

# %%
class ReplayBuffer:
    """
    Implements a fixed-size buffer to store experience tuples.

    Attributes:
        memory (deque): Internal memory buffer that stores experiences.
        batch_size (int): Size of each training batch.
        experience (namedtuple): Namedtuple defining an experience for storage in the buffer.

    Args:
        buffer_size (int): Maximum size of the buffer.
        batch_size (int): Size of each training batch.
        seed (int): Random seed for reproducibility.
    """

    def __init__(self, buffer_size, batch_size, seed):
        self.memory = deque(maxlen=buffer_size)
        self.seed = random.seed(seed)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])

    def add(self, state, action, reward, next_state, done):
        """
        Adds an experience to the buffer.

        Args:
            state: The state observed from the environment.
            action: The action taken in the environment.
            reward: The reward received from the environment.
            next_state: The next state observed from the environment after the action is taken.
            done: Boolean flag indicating if the episode has ended.
        """
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """
        Randomly samples a batch of experiences from memory.

        Returns:
            Tuple[Tensor]: Tuple of tensors corresponding to states, actions, rewards, next_states, and dones.
        """
        experiences = random.sample(self.memory, k=self.batch_size)
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """
        Returns the current size of internal memory.

        Returns:
            int: The current size of the memory buffer.
        """
        return len(self.memory)

# %% [markdown]
# ## Define the DQN Agent and Hyperparameters
# Apart from defining the DQN network and the replay buffer, we also define the DQN agent. The DQN agent has methods to take actions, learn from experiences, and update the target network. We also define the hyperparameters for training the DQN agent. These parameters can be tuned to improve the performance of the agent.

# %%
BUFFER_SIZE = 50_000
BATCH_SIZE = 128
UPDATE_INTERVAL = 10
GAMMA = 0.99
TAU = 1
LR = 1e-3

MAX_EPISODES = 2000
MAX_STEPS = 1000
SOLVED_THRESHOLD = 200
LOG_INTERVAL = 20

EPS_START = 1.0
EPS_END = 0.01
EPS_DECAY = 0.995

# %% [markdown]
# ## Define the DQN Agent
# The DQN Agent is responsible for taking actions, learning from experiences, and updating the target network. The agent has methods to take actions, learn from experiences, and update the target network. The agent also has a method to save the model weights to a file.

# %%
class DQNAgent:
    """
    Represents an agent that uses a Deep Q-Network (DQN) for learning policies based on the Q-learning algorithm.

    Attributes:
        state_size (int): The dimensionality of the state space.
        action_size (int): The dimensionality of the action space.
        seed (int): Random seed for reproducibility.
        q_network (DQNNetwork): The primary network used for estimating Q-values.
        target_network (DQNNetwork): The target network used for calculating target Q-values.
        optimizer (torch.optim.Adam): Optimizer for training q_network.
        memory (ReplayBuffer): Replay buffer for storing and sampling experiences.
        t_step (int): Internal counter to track when to update the target network.

    Args:
        state_size (int): The dimensionality of the state space.
        action_size (int): The dimensionality of the action space.
        seed (int): Seed for random number generators to ensure reproducibility.
    """
    def __init__(self, state_size, action_size, seed):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        self.q_network = DQNNetwork(state_size, action_size, seed).to(device)
        self.target_network = DQNNetwork(state_size, action_size, seed).to(device)
        self.optmizer = optim.Adam(self.q_network.parameters(), lr=LR)
        self.memory = ReplayBuffer(BUFFER_SIZE, BATCH_SIZE, seed)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        """
        Processes a step taken by the agent by saving the experience in replay memory and potentially
        learning from a sample of experiences from the memory.

        Args:
            state: The current state observed in the environment.
            action: The action taken by the agent.
            reward: The reward received after taking the action.
            next_state: The next state observed after taking the action.
            done: Boolean indicating whether the episode has finished.
        """
        self.memory.add(state, action, reward, next_state, done)
        self.t_step += 1
        if self.t_step % UPDATE_INTERVAL == 0:
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences)

    def learn(self, experiences):
        """
        Updates Q-network based on a batch of experiences.

        Args:
            experiences (Tuple[torch.Tensor]): Tuple of tensors (states, actions, rewards, next_states, dones).
        """
        states, actions, rewards, next_states, dones = experiences
        action_values = self.q_network(next_states).detach()
        max_action_values = action_values.max(1)[0].unsqueeze(1)

        q_target = rewards + (GAMMA * max_action_values * (1 - dones))
        q_expected = self.q_network(states).gather(1, actions)

        loss = F.mse_loss(q_expected, q_target)
        self.optmizer.zero_grad()

        loss.backward()
        self.optmizer.step()

        self.update_target_network(self.q_network, self.target_network)

    def update_target_network(self, q_network, target_network):
        """
        Soft updates the target network parameters.

        Args:
            q_network (DQNNetwork): The primary network from which weights are copied.
            target_network (DQNNetwork): The target network to which weights are copied.
        """
        for source, target in zip(q_network.parameters(), target_network.parameters()):
            target.data.copy_(TAU * source.data + (1.0 - TAU) * target.data)

    def act(self, state, eps=0.0):
        """
        Returns actions for given state as per current policy.

        Args:
            state: The current state of the environment.
            eps (float): epsilon, for epsilon-greedy action selection.

        Returns:
            int: The action chosen by the agent.
        """
        rnd_val = random.random()
        if rnd_val < eps:
            return np.random.randint(self.action_size)
        else:
            state = torch.from_numpy(state).float().unsqueeze(0).to(device)
            self.q_network.eval()
            with torch.no_grad():
                action_values = self.q_network(state)
            self.q_network.train()
            return np.argmax(action_values.cpu().data.numpy())

    def save(self, path):
        """
        Saves the model state dictionary to the specified path.

        Args:
            path (str): File path to save the model state dictionary.
        """
        torch.save(self.q_network.state_dict(), path)

# %% [markdown]
# ## Training Loop
# To train the DQN agent, we define the training loop. In the training loop, we iterate over episodes and steps within each episode. We take actions, learn from experiences, and update the target network. We also keep track of the scores and the mean score over the last 100 episodes. The training loop continues until the environment is solved or the maximum number of episodes is reached.

# %% [markdown]
# ### Initialize the Environment and Agent

# %%
env = gym.make('LunarLander-v2')

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

print(f"State size: {state_size}, Action size: {action_size}")
agent = DQNAgent(state_size, action_size, seed=42)
# Out:
# State size: 8, Action size: 4

# %% [markdown]
# ### Train the DQN Agent

# %%
scores = []
score_window = deque(maxlen=100)
eps = EPS_START

for episode in range(1, MAX_EPISODES):
    state, info = env.reset()
    score = 0
    reached_terminal = False
    for step in range(MAX_STEPS):
        action = agent.act(state, eps)
        next_state, reward, done, truncated, info = env.step(action)
        agent.step(state, action, reward, next_state, done)
        state = next_state
        score += reward
        if done:
            break

        if episode % (LOG_INTERVAL * 4) == 0:
            eps = max(EPS_END, EPS_DECAY * eps)

        if episode % LOG_INTERVAL == 0:
            mean_score = np.mean(score_window)
            print(f"Episode {episode}, Score: {score:.2f}, Eps: {eps:.2f}, Mean Score: {mean_score:.2f}")
            if mean_score >= SOLVED_THRESHOLD:
                print(f"Environment solved in {episode} episodes")
                print(f"Mean score: {mean_score:.2f}")
                agent.save("dqn_lunar_lander.pth")
                reached_terminal = True
                break
    score_window.append(score)
    scores.append(score)
    if reached_terminal:
        break
env.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 460, Score: 89.73, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 91.48, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 92.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 93.17, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 93.74, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 95.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 95.34, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 91.08, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 93.95, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 96.08, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 93.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 94.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 92.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 94.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 91.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 92.26, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 87.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.99, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 85.78, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 87.65, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 86.53, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 86.56, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 87.45, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 89.06, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 89.55, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 87.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 90.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 90.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.03, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 90.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 87.32, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 90.25, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 92.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 92.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 89.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 91.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 89.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 89.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 86.27, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 88.36, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 84.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 85.85, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 83.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 84.32, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 82.15, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 82.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 78.93, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 79.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 79.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 78.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.20, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.75, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 74.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 74.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 76.47, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 74.17, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 73.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 69.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.60, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.67, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.05, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.81, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 63.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.12, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.81, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.85, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.27, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 64.93, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.09, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.03, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.20, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 69.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 72.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 73.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 73.15, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 73.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 75.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 77.36, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 75.60, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 72.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 71.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 69.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.07, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.75, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.09, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.26, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 63.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.67, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 69.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.07, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 70.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 69.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 68.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.17, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.95, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.73, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 67.47, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 66.06, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.01, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 63.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 64.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 63.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 65.04, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 62.22, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 63.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 59.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 60.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 57.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 57.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.48, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.31, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.26, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 50.56, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.36, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.41, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 50.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.05, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 57.01, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 57.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 58.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 58.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 55.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 58.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.45, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 59.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 58.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 58.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 59.43, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.04, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.45, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 56.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 54.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 51.41, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 53.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 51.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 49.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 52.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 48.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 50.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 49.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 50.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 48.35, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.66, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.41, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.60, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 43.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 43.79, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.63, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.76, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.01, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.17, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 42.48, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.15, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 43.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 46.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.79, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 43.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 47.09, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 44.56, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 45.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 42.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 40.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 41.06, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 39.47, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.56, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.06, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 34.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 34.84, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 33.73, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 33.63, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 33.96, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 34.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 39.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.15, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 39.20, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 39.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 33.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 38.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 37.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 34.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.52, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 36.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 30.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 35.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 31.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 33.52, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 31.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 32.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 31.27, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 30.98, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 26.62, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 28.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 30.25, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 28.32, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 28.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 26.38, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 26.55, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 25.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 24.96, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 21.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 22.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 22.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 21.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.34, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 20.83, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.29, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 20.84, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.04, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.93, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.34, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 21.31, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 22.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 23.32, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 21.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 23.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 19.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.72, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.99, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.36, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.64, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 9.72, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 9.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 9.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.85, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 9.38, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.41, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.06, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.82, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.35, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.90, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.29, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.65, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.71, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 16.55, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.43, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.60, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.82, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 17.76, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.07, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 16.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.08, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 16.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 16.37, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 18.28, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 15.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.74, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 14.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.43, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 13.34, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.43, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 11.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 12.01, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 10.76, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.80, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.60, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.32, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 7.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 7.73, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.81, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 7.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.86, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.75, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 4.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.78, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.31, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 4.44, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.84, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 2.84, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 1.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.79, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 2.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.77, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.73, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 4.65, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 7.20, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.56, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.40, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.14, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.07, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.48, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 8.57, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 6.04, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 7.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 5.99, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 4.19, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 2.20, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 3.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 1.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: 0.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -2.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -0.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -2.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -2.29, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -5.30, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -4.51, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.74, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.59, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -8.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -5.29, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.18, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -4.47, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -3.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -3.95, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -5.65, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -3.35, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.27, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -3.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -4.97, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -2.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.46, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -3.94, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -4.43, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -5.63, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -8.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -6.13, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.96, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.16, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.25, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.91, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -8.33, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.52, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -8.00, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -7.50, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.47, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -11.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -9.29, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -11.15, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -10.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -12.49, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -10.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -12.78, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.76, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.01, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -14.35, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.17, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -11.76, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -12.22, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.34, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -11.70, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.24, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.87, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -12.58, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.08, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -14.48, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -14.53, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -14.93, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.55, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -13.96, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -16.11, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -16.03, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -15.54, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -18.61, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -20.92, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -19.68, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -18.42, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -18.69, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -21.26, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -19.21, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -20.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -23.02, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -22.27, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -19.89, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -22.84, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -22.23, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -23.39, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -23.88, Eps: 0.01, Mean Score: -68.73
# Episode 460, Score: -23.58, Eps: 0.01, Mean Score: -68.73
# Episode 480, Score: -0.12, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -0.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -0.22, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 0.03, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 0.35, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 0.42, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -0.51, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -1.62, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -3.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: -2.20, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 1.52, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 2.98, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 4.95, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 7.39, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 9.16, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 11.10, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 13.89, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 15.10, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 17.21, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 20.00, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 22.77, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 24.62, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 27.10, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 29.15, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 29.55, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 31.97, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 32.31, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 33.56, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 34.47, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 37.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 37.95, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 42.32, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 43.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 40.52, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 44.27, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 41.63, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 43.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 41.32, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 43.83, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 45.49, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 43.32, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 44.58, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 42.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 44.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 42.65, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 40.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 39.46, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 37.42, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 36.13, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 34.27, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 33.12, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 31.49, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 30.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 29.54, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 28.33, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 29.90, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 32.04, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 34.80, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 39.57, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 38.81, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 44.04, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 46.56, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 49.27, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 50.81, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 54.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 53.94, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 52.54, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 55.55, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 58.83, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 62.31, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 65.83, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 65.52, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 65.95, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 68.40, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 70.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 72.14, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 73.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 74.42, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 77.85, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.16, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.34, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 86.66, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.69, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.50, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.73, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.55, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 84.98, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 82.93, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 81.94, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 79.80, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.21, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 79.79, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 79.46, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.91, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.88, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 79.03, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.11, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.48, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 74.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 72.87, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 74.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 73.83, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 75.49, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 75.20, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 75.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.12, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.20, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 76.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 79.30, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 77.99, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.01, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.60, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 77.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 77.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.44, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.01, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.48, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 78.45, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.10, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 81.26, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.31, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 80.81, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.56, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 82.68, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.02, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 82.19, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 81.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 81.85, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 82.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 81.98, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 83.79, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 84.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 86.04, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 84.54, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 86.11, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.32, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.62, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.20, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.26, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.72, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.98, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.69, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.75, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.34, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.23, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.28, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.78, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.44, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.24, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.19, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.22, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.44, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.13, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.22, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.95, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.98, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.66, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.53, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.32, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.66, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.31, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.74, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.60, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.29, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.40, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.25, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.33, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.06, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.03, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.37, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.53, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.25, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.90, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.47, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.89, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.68, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.00, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.77, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.03, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.17, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.05, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.46, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.14, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.67, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.57, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.75, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.85, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.58, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.25, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.23, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.07, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.21, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.77, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.65, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.94, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.00, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 97.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.90, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.26, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.56, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.70, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.58, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.95, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.48, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.35, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.66, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.94, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.74, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.41, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.68, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.16, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.42, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.69, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.82, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.93, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.27, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.62, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.34, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.74, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.15, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.19, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.13, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.33, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.07, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.63, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.53, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.08, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.93, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.28, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 95.70, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.40, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 96.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.76, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.61, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.40, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.10, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 85.84, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.56, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.84, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.60, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.96, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 94.63, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.44, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.78, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.38, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.52, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.02, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.59, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.92, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.43, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.68, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.87, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 91.94, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.22, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.25, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 93.88, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 92.02, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 89.88, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.65, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 90.64, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 88.35, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 86.01, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 86.29, Eps: 0.01, Mean Score: -68.35
# Episode 480, Score: 87.86, Eps: 0.01, Mean Score: -68.35
# ...
# Episode 680, Score: -5.83, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: -4.32, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: -0.82, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: -0.35, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 0.53, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 3.48, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 7.46, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 5.53, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 7.40, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 9.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 12.85, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 10.79, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 10.98, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 12.64, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 16.48, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 14.54, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 14.71, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 13.33, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 16.55, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 20.08, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 19.00, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 21.42, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 25.51, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 24.08, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 23.10, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 27.15, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 27.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 30.57, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 30.11, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 31.09, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 34.64, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 34.43, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 33.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 37.57, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 36.26, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 36.07, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 39.81, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 38.48, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 40.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 40.74, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 39.78, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 37.98, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 39.76, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 40.44, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 43.27, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 41.47, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 39.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 40.43, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 43.33, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 44.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 48.22, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 46.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 49.40, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 47.76, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 45.52, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 46.45, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 49.38, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 50.42, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 54.60, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 54.42, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 55.82, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 60.19, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 58.46, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 56.25, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 58.75, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 61.73, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 59.58, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 63.39, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 61.72, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 64.69, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 62.60, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 65.92, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 64.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 66.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 64.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 69.64, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 67.71, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 65.87, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 68.04, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 71.04, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 69.44, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 67.80, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 69.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 72.41, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 70.83, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 73.90, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 74.89, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 77.97, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 76.72, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 75.16, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 80.01, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 78.73, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 81.31, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 82.68, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 87.78, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 86.02, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 86.77, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 89.31, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 91.39, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 89.72, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 92.69, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 90.76, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 91.19, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 93.46, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 95.62, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 98.44, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 96.92, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 98.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 100.25, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 98.31, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 98.99, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 101.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 102.28, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 105.41, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 107.32, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 105.03, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 103.33, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 105.32, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 105.86, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 109.51, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 113.30, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 111.12, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 112.21, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 115.47, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 114.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 114.30, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 115.52, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 118.02, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 115.45, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 117.70, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 115.33, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 113.52, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 117.12, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 120.01, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 120.41, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 122.68, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 120.42, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 118.45, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 121.63, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 123.16, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 120.79, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 118.86, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 121.93, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 124.91, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 122.54, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 125.44, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 123.64, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 126.27, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 123.85, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 125.01, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.52, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 126.29, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 124.88, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 127.39, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 125.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 127.37, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.97, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 126.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 126.46, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.31, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 127.94, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.91, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.05, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.15, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.72, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.12, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.51, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.05, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.28, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.36, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.21, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.03, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.09, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.89, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 135.09, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.13, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.99, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.94, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.05, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.37, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.10, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.60, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.30, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 134.43, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.03, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.92, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.18, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.07, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.32, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.76, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.13, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.48, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 126.86, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 127.45, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.69, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.76, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.27, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 128.77, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.68, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.49, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.11, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.58, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.45, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.15, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.80, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.19, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.84, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.86, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 134.06, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.11, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.49, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.97, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.88, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.14, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 134.57, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.96, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.04, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.56, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 134.42, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.90, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.75, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.13, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 134.81, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 133.52, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 131.22, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.80, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 130.25, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 132.55, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 129.62, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 143.02, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 142.24, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 154.73, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 154.54, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.55, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.59, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.29, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.64, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.65, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.22, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 680, Score: 155.61, Eps: 0.01, Mean Score: 192.18
# Episode 700, Score: 0.17, Eps: 0.01, Mean Score: 218.63
# Environment solved in 700 episodes
# Mean score: 218.63

# %% [markdown]
# ## Plotting the Resulting Scores [Reward x Episode]
# Analying the scores obtained during the training process can help us understand how the agent is learning. We can plot the scores obtained during the training process to visualize the agent's learning progress.

# %%
# Plot the scores
plt.figure(figsize=(10, 5))
plt.plot(scores)

# Calculate the rolling mean of the scores to smooth the curve
plt.plot(pd.Series(scores).rolling(100).mean(), label="Rolling mean")

# Plot the threshold line
plt.title("DQN Lunar Lander")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ## Evaluate the Agent - Viewing the Agent's Behavior in the Environment
# After training the agent, we can evaluate the agent's performance by running the agent in the environment and observing its behavior. We can render the environment and observe the agent's actions.

# %% [markdown]
# ### Load the Trained Model
# Since we have saved the model weights to a file, we can load the model weights and use the model to evaluate the agent.

# %%
agent.q_network.load_state_dict(torch.load('dqn_lunar_lander.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Evaluate the Agent

# %%
# Initialize the environment
env = gym.make('LunarLander-v2', render_mode="rgb_array")

# Define a trigger function to record the video
trigger = lambda t: t % 1 == 0
env = gym.wrappers.RecordVideo(env, video_folder="/videos", episode_trigger=trigger, disable_logger=True)

# Evaluate the agent
for i in range(1):
  termination, truncation = False, False
  eval_state, _ = env.reset()
  while not (termination or truncation):
    action = agent.act(eval_state)
    obs, rew, termination, truncated, info = env.step(action)
    eval_state = obs

# %% [markdown]
# ### Display the Video

# %%
video_path = 'videos/rl-video-episode-0.mp4'
display(Video(video_path, embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
